# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'anarchism', 'a', 'of', 'originated', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print(embed.get_shape())
  print(embed.get_shape())  
  print(embed.get_shape())
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# embeddings (50000, 128)
# train_dataset (128,)
# embed (128, 128)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.171535
# Nearest to used: catfish, nbc, easton, irregularity, deteriorated, withstand, interrogating, ibo,
# Nearest to by: sculptures, bambaataa, dogme, polgar, preferentially, syndicated, omphale, flanks,
# Nearest to be: puns, breviary, goalscorer, rewarded, dragoons, pamphilus, consumes, groundwater,
# Nearest to into: rence, overcomes, generosity, asteroids, lantau, martinique, backwardness, freitas,
# Nearest to of: inspection, tabari, philanthropic, ushering, ruskin, hitchens, reclassification, gorillas,
# Nearest to seven: haarlem, feuding, amit, ecs, cardboard, demoted, somali, thunderstorms,
# Nearest to had: slugger, stupa, valkyrie, untenable, puncture, racquets, albertosaurus, worthwhile,
# Nearest to state: lillian, amazing, resurgent, etruscans, widows, sliders, programme, linkage,
# Nearest to from: metabolism, vincennes, nkrumah, christensen, wembley, wane, pontus, contraception,
# Nearest to states: clich, revolted, disambiguation, janusz, facilitating, spaniard, prolog, gebhard,
# Nearest to use: wine, employs, intellivision, publ, figaro, discussion, elegies, excavations,
# Nearest to american: apologetics, claw, erection, fortified, osama, cmyk, codeine, customization,
# Nearest to five: matteo, oldsmobile, guam, hangings, conferred, hirschfeld, nbc, collegium,
# Nearest to it: crts, commercialism, episkopos, bosniak, lagoons, include, marcos, massed,
# Nearest to at: meddling, chaining, verb, lewinsky, id, lichtenberg, mentioning, assessed,
# Nearest to however: kalat, existed, bryce, restorer, farther, whereof, maharishi, bri,
# Average loss at step 2000: 4.357544
# Average loss at step 4000: 3.866065
# Average loss at step 6000: 3.786988
# Average loss at step 8000: 3.688943
# Average loss at step 10000: 3.610175
# Nearest to used: deteriorated, magick, nbc, floors, held, dagobert, wash, gesenius,
# Nearest to by: was, femininity, at, draugr, ergaster, in, dekker, been,
# Nearest to be: have, thrilling, infectious, breviary, do, was, nik, versailles,
# Nearest to into: from, martinique, correspondence, mabo, brochs, overcomes, under, stabilize,
# Nearest to of: in, cayley, and, for, uterus, tibesti, videotape, at,
# Nearest to seven: eight, six, nine, three, five, four, zero, two,
# Nearest to had: have, has, was, rsc, metrolink, cry, whereupon, radioisotope,
# Nearest to state: limited, needs, all, widows, sliders, sunrise, inefficiencies, etruscans,
# Nearest to from: in, into, between, technicolor, munition, at, whatsoever, for,
# Nearest to states: discovery, manu, dishonest, disambiguation, fixing, infamy, distress, rwanda,
# Nearest to use: form, figaro, intellivision, halo, darwin, wine, discussion, melbourne,
# Nearest to american: political, sprengel, apologetics, nsh, osama, matheson, codeine, floss,
# Nearest to five: six, nine, eight, four, three, seven, zero, two,
# Nearest to it: he, there, this, she, not, which, they, capo,
# Nearest to at: grass, in, by, on, during, from, meddling, isps,
# Nearest to however: dib, kalat, existed, doo, bri, fathered, bios, farther,
# Average loss at step 12000: 3.607042
# Average loss at step 14000: 3.572857
# Average loss at step 16000: 3.404109
# Average loss at step 18000: 3.452526
# Average loss at step 20000: 3.542234
# Nearest to used: known, held, moser, campo, floors, possible, spinal, zander,
# Nearest to by: ergaster, be, for, in, mabo, burundian, sobriety, been,
# Nearest to be: have, been, were, by, is, was, become, mean,
# Nearest to into: from, under, in, mabo, martinique, with, aelian, between,
# Nearest to of: main, for, in, marketshare, at, permits, inspection, ephraim,
# Nearest to seven: eight, nine, six, five, four, three, zero, two,
# Nearest to had: has, have, was, were, torpedoes, rsc, whereupon, propositions,
# Nearest to state: needs, limited, leaders, necropolis, inefficiencies, workings, hops, xxii,
# Nearest to from: into, in, and, between, at, rabbah, through, after,
# Nearest to states: dishonest, discovery, manu, yeltsin, resources, francais, infamy, onscreen,
# Nearest to use: form, figaro, cause, intellivision, melbourne, discussion, work, halo,
# Nearest to american: political, headers, british, birthdays, russian, sponge, canadian, sprengel,
# Nearest to five: six, three, seven, eight, four, two, zero, nine,
# Nearest to it: he, this, there, she, they, which, not, liberalisation,
# Nearest to at: in, on, with, from, during, for, upon, and,
# Nearest to however: but, that, fathered, lakatos, rebranded, kalat, doo, bri,
# Average loss at step 22000: 3.502595
# Average loss at step 24000: 3.492344
# Average loss at step 26000: 3.480136
# Average loss at step 28000: 3.479842
# Average loss at step 30000: 3.499710
# Nearest to used: known, moser, found, written, held, common, campo, spinal,
# Nearest to by: unlucky, femininity, draugr, dogme, verbatim, theravada, apotheosis, in,
# Nearest to be: have, been, is, become, mean, were, was, are,
# Nearest to into: from, under, aelian, through, mabo, within, in, on,
# Nearest to of: in, cayley, from, for, ephraim, marketshare, technical, permits,
# Nearest to seven: eight, nine, three, five, four, six, zero, one,
# Nearest to had: has, have, was, were, having, affordable, is, been,
# Nearest to state: needs, leaders, necropolis, group, slits, spitzer, sunrise, achill,
# Nearest to from: into, in, after, under, of, utilizes, on, munition,
# Nearest to states: dishonest, manu, discovery, yeltsin, onscreen, hebrides, kingdom, francais,
# Nearest to use: form, figaro, cause, harden, intellivision, discussion, cairn, enhance,
# Nearest to american: british, english, headers, russian, australian, canadian, german, austrian,
# Nearest to five: four, eight, three, six, seven, nine, zero, two,
# Nearest to it: he, there, she, this, they, which, not, vary,
# Nearest to at: in, on, grass, during, amadeus, featureless, before, upon,
# Nearest to however: but, that, although, subsidiary, lakatos, where, when, maharishi,
# Average loss at step 32000: 3.500115
# Average loss at step 34000: 3.491835
# Average loss at step 36000: 3.456280
# Average loss at step 38000: 3.299012
# Average loss at step 40000: 3.425157
# Nearest to used: known, found, referred, considered, written, moser, held, responsible,
# Nearest to by: been, ergaster, tachyon, when, crawford, utilizes, draugr, with,
# Nearest to be: been, have, is, are, become, were, being, artcyclopedia,
# Nearest to into: from, through, aelian, under, res, index, fronti, intermittent,
# Nearest to of: in, cayley, gleason, forbade, famicom, valentinus, same, inspection,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to had: has, have, was, were, radiocommunication, began, having, been,
# Nearest to state: needs, sunrise, necropolis, deshima, spitzer, calabria, hops, leaders,
# Nearest to from: into, hjalmar, tibesti, utilizes, in, under, oakenfold, through,
# Nearest to states: kingdom, nations, headlines, dishonest, hebrides, distress, manu, francais,
# Nearest to use: form, cause, harden, loss, natures, cairn, outside, figaro,
# Nearest to american: german, russian, british, australian, headers, birthdays, english, quod,
# Nearest to five: six, seven, three, four, eight, zero, nine, two,
# Nearest to it: he, there, she, this, they, which, liberalisation, still,
# Nearest to at: during, grass, on, in, amadeus, before, dez, echoes,
# Nearest to however: but, that, although, lgpl, judiciary, since, while, lakatos,
# Average loss at step 42000: 3.437104
# Average loss at step 44000: 3.451943
# Average loss at step 46000: 3.447373
# Average loss at step 48000: 3.349261
# Average loss at step 50000: 3.379647
# Nearest to used: known, referred, considered, written, found, seen, regarded, moser,
# Nearest to by: through, with, ergaster, was, among, distantly, dogme, in,
# Nearest to be: have, been, become, were, was, being, is, are,
# Nearest to into: from, through, under, back, res, aelian, on, pulaski,
# Nearest to of: in, cayley, and, including, iterative, empties, proverbs, entire,
# Nearest to seven: eight, six, nine, three, four, five, zero, two,
# Nearest to had: has, have, was, were, having, gained, incurable, radiocommunication,
# Nearest to state: calabria, needs, achill, deshima, linkage, hostage, sunrise, uneven,
# Nearest to from: into, in, through, after, between, during, since, under,
# Nearest to states: kingdom, nations, dishonest, awakened, headlines, francais, hebrides, laws,
# Nearest to use: form, cause, support, most, loss, outside, cairn, workload,
# Nearest to american: english, russian, german, australian, birthdays, headers, austrian, cochran,
# Nearest to five: four, six, eight, seven, three, zero, nine, two,
# Nearest to it: he, there, she, this, they, still, also, electromotive,
# Nearest to at: during, in, zamboanga, echoes, amadeus, beet, trolling, lambs,
# Nearest to however: but, although, that, when, while, though, where, physiocrats,
# Average loss at step 52000: 3.437655
# Average loss at step 54000: 3.424443
# Average loss at step 56000: 3.436502
# Average loss at step 58000: 3.393613
# Average loss at step 60000: 3.394434
# Nearest to used: known, considered, referred, written, found, seen, responsible, moser,
# Nearest to by: through, ergaster, gondor, among, distantly, boarded, xii, ecoregion,
# Nearest to be: been, have, become, is, were, was, being, are,
# Nearest to into: through, from, res, under, pulaski, back, aelian, within,
# Nearest to of: in, for, unofficial, entire, expressionism, and, iterative, same,
# Nearest to seven: eight, four, six, nine, five, three, one, zero,
# Nearest to had: has, have, was, gained, were, having, been, took,
# Nearest to state: calabria, achill, needs, necropolis, territory, deshima, government, hostage,
# Nearest to from: into, through, in, between, restraints, after, since, malevich,
# Nearest to states: kingdom, nations, dishonest, headlines, bolder, basques, yeltsin, languedoc,
# Nearest to use: cause, most, support, outside, represent, form, surpasses, emblematic,
# Nearest to american: australian, german, russian, birthdays, english, international, british, indian,
# Nearest to five: six, three, four, seven, eight, zero, nine, two,
# Nearest to it: he, there, she, this, they, still, what, now,
# Nearest to at: in, during, grass, kmaq, within, without, zamboanga, amadeus,
# Nearest to however: but, although, though, that, when, while, interpretive, since,
# Average loss at step 62000: 3.239048
# Average loss at step 64000: 3.248385
# Average loss at step 66000: 3.402720
# Average loss at step 68000: 3.391081
# Average loss at step 70000: 3.357594
# Nearest to used: known, considered, found, referred, written, responsible, seen, designed,
# Nearest to by: through, ergaster, propensity, xhtml, be, xii, shays, from,
# Nearest to be: been, being, become, have, were, is, was, are,
# Nearest to into: through, from, res, under, fpu, back, within, towards,
# Nearest to of: including, for, and, manichaean, original, amit, unofficial, inject,
# Nearest to seven: six, eight, nine, four, five, three, two, zero,
# Nearest to had: have, has, was, having, were, recently, been, metrolink,
# Nearest to state: calabria, department, achill, kilda, needs, necropolis, deshima, linkage,
# Nearest to from: into, through, in, hjalmar, after, between, restraints, within,
# Nearest to states: kingdom, nations, basques, distress, countries, us, headlines, bolder,
# Nearest to use: cause, represent, form, outside, strength, emblematic, support, send,
# Nearest to american: english, australian, german, british, tagalog, olomouc, quod, investiture,
# Nearest to five: four, six, three, seven, eight, zero, nine, two,
# Nearest to it: he, she, there, this, they, still, also, which,
# Nearest to at: during, in, dispensation, grass, hashshashin, before, within, favourite,
# Nearest to however: but, although, though, while, where, that, abydos, since,
# Average loss at step 72000: 3.369115
# Average loss at step 74000: 3.352351
# Average loss at step 76000: 3.311857
# Average loss at step 78000: 3.346973
# Average loss at step 80000: 3.381072
# Nearest to used: known, referred, responsible, written, considered, found, seen, available,
# Nearest to by: through, xii, distantly, ergaster, teenager, burundian, and, unlucky,
# Nearest to be: been, being, have, become, were, thrilling, is, mean,
# Nearest to into: through, from, res, back, within, under, pulaski, towards,
# Nearest to of: proverbs, including, in, cayley, entire, marketshare, glutamic, boutros,
# Nearest to seven: six, eight, five, four, three, nine, zero, two,
# Nearest to had: have, has, having, were, was, gained, took, never,
# Nearest to state: kilda, city, department, deshima, government, achill, territory, governor,
# Nearest to from: into, through, munition, within, under, after, in, between,
# Nearest to states: kingdom, nations, us, headlines, basques, distress, bolder, yeltsin,
# Nearest to use: cause, form, support, represent, emblematic, because, surpasses, rab,
# Nearest to american: british, australian, german, russian, tagalog, olomouc, irish, ear,
# Nearest to five: four, six, seven, three, eight, nine, zero, two,
# Nearest to it: he, she, there, this, they, we, electromotive, itself,
# Nearest to at: in, during, dispensation, on, beet, under, hashshashin, kmaq,
# Nearest to however: although, but, that, though, while, where, since, abydos,
# Average loss at step 82000: 3.406913
# Average loss at step 84000: 3.410678
# Average loss at step 86000: 3.391330
# Average loss at step 88000: 3.351451
# Average loss at step 90000: 3.360830
# Nearest to used: referred, known, applied, considered, seen, responsible, found, written,
# Nearest to by: through, with, draugr, during, unstated, from, thuringiensis, ergaster,
# Nearest to be: been, become, have, being, is, was, puns, easily,
# Nearest to into: through, from, res, under, within, lms, on, prussian,
# Nearest to of: including, for, proverbs, during, in, include, bbl, iterative,
# Nearest to seven: eight, five, nine, four, six, three, zero, two,
# Nearest to had: has, have, were, was, having, began, gained, been,
# Nearest to state: city, department, government, calabria, achill, sunrise, deshima, uneven,
# Nearest to from: into, through, under, after, within, malevich, islamism, before,
# Nearest to states: kingdom, nations, us, bolder, headlines, hortense, reloaded, basques,
# Nearest to use: support, because, most, cause, lack, outside, basis, surpasses,
# Nearest to american: british, australian, german, french, russian, indian, irish, cuban,
# Nearest to five: four, seven, eight, six, three, two, nine, zero,
# Nearest to it: he, she, there, this, they, itself, actually, we,
# Nearest to at: during, without, dispensation, grass, zamboanga, under, after, once,
# Nearest to however: but, although, that, though, since, while, where, cases,
# Average loss at step 92000: 3.397122
# Average loss at step 94000: 3.256102
# Average loss at step 96000: 3.356059
# Average loss at step 98000: 3.246133
# Average loss at step 100000: 3.356449
# Nearest to used: referred, applied, written, found, responsible, considered, seen, designed,
# Nearest to by: without, including, through, ergaster, when, distantly, during, xii,
# Nearest to be: been, have, being, easily, puns, become, are, were,
# Nearest to into: through, from, within, res, under, in, towards, on,
# Nearest to of: including, in, stressful, famicom, deutsche, banchan, and, nanomachines,
# Nearest to seven: eight, four, five, six, nine, three, zero, two,
# Nearest to had: has, have, was, having, were, would, gained, won,
# Nearest to state: city, department, government, uneven, kilda, mmc, governor, hops,
# Nearest to from: into, in, through, within, munition, onto, via, during,
# Nearest to states: nations, kingdom, us, bolder, headlines, forces, sustainable, reloaded,
# Nearest to use: support, cause, usage, loss, form, inference, amusing, basis,
# Nearest to american: australian, british, italian, att, canadian, headers, irish, indian,
# Nearest to five: four, seven, six, eight, three, nine, zero, two,
# Nearest to it: he, she, this, there, they, what, electromotive, bingu,
# Nearest to at: during, in, after, within, on, under, zamboanga, dispensation,
# Nearest to however: but, although, that, though, while, where, especially, eclipse,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
    global data_index  
    batch = np.ndarray(shape=(batch_size, skip_window * 2), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    
    for i in xrange(batch_size):        
        for j in xrange(skip_window):
            batch[i, j] = buffer[j]        
            batch[i, skip_window + j] = buffer[skip_window + 1 + j]
        labels[i] = buffer[skip_window]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('\nwith skip_window = %d:' % (skip_window, ))
    print('    batch:', [[reverse_dictionary[bi] for bi in b] for b in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, skip_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    print('train_dataset', train_dataset.get_shape())

    # Model.
    # Look up embeddings for inputs.
    embed = []
    for i in xrange(skip_window * 2):
        embed.append(tf.nn.embedding_lookup(embeddings, train_dataset[:, i]))
    
    print('embed', len(embed), embed[0].get_shape())
    all_embed = tf.stack(embed, axis=2)
    avg_embed = tf.reduce_mean(all_embed, axis=2)
    
    print('all_embed', all_embed.get_shape())
    print('avg_embed', avg_embed.get_shape())
    
    print('embeddings', embeddings.get_shape())
    print('train_dataset', train_dataset.get_shape())  

    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, avg_embed,
                                   train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# train_dataset (128, 2)
# embed 2 (128, 128)
# all_embed (128, 128, 2)
# avg_embed (128, 128)
# embeddings (50000, 128)
# train_dataset (128, 2)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.514548
# Nearest to its: syllabics, dominicans, marienburg, comedy, virtue, belushi, deficit, constructivists,
# Nearest to however: holiday, handhelds, sasl, rensselaer, leveraged, goalkeeper, regatta, principle,
# Nearest to more: gpl, kent, photographers, evict, spalding, ndp, nee, brookline,
# Nearest to be: stuttgart, labored, shaughnessy, paperback, kanons, thespis, usurpation, doings,
# Nearest to of: concurrency, enclosed, clytemnestra, portsmouth, accommodated, watson, mosfet, ginette,
# Nearest to united: priming, habsburg, utilize, bloodlines, restraints, requiring, mathura, licence,
# Nearest to at: colchester, skull, moist, dreadful, tragedians, dawkins, vickers, strand,
# Nearest to time: willing, checked, brawl, communities, teaming, scarlet, destinations, cucumbers,
# Nearest to may: irresponsibility, redshift, stratum, expeditionary, inspections, identifiable, normally, metabolism,
# Nearest to has: mandolins, taunted, longhair, pcc, merlot, idaho, circuitry, deal,
# Nearest to history: redrawing, homeworld, demeter, spared, gothic, cordova, arianespace, shemini,
# Nearest to known: seer, audubon, detriment, magnets, cecilia, cpc, distinctly, calls,
# Nearest to world: alomari, subfields, counseling, declines, ztas, bijapur, infidelity, gallia,
# Nearest to than: quadra, lucie, overthrowing, mini, knit, bethlehem, snobol, hh,
# Nearest to war: iigs, irv, clapping, embodying, membrane, xcd, jai, delivering,
# Nearest to but: xie, hexagon, location, fft, karakoram, springer, shrews, froze,
# Average loss at step 2000: 4.027609
# Average loss at step 4000: 3.511046
# Average loss at step 6000: 3.343492
# Average loss at step 8000: 3.196747
# Average loss at step 10000: 3.153055
# Nearest to its: the, their, his, avery, torch, this, comedy, her,
# Nearest to however: but, leveraged, regatta, about, holiday, cutters, where, randal,
# Nearest to more: syllable, nee, ponds, rather, superceded, touring, kent, carnap,
# Nearest to be: have, doings, refer, was, were, labored, is, amal,
# Nearest to of: concurrency, enclosed, watson, lachaise, portsmouth, fis, selby, within,
# Nearest to united: utilize, mathura, priming, requiring, senate, restraints, inspires, same,
# Nearest to at: until, in, during, on, antofagasta, colchester, conqueror, bingen,
# Nearest to time: communities, unproven, year, vinton, wonders, pepe, scarlet, dashes,
# Nearest to may: can, could, must, should, will, might, shards, would,
# Nearest to has: had, have, was, is, dachau, rammstein, ladders, though,
# Nearest to history: homeworld, implosive, sobib, spared, beads, grantham, arianespace, university,
# Nearest to known: seer, such, well, tretyakov, cerf, used, detriment, raceway,
# Nearest to world: counseling, alomari, ztas, bijapur, sheridan, tau, racial, profession,
# Nearest to than: quadra, michele, smirnov, hooking, overthrowing, or, struggling, amnon,
# Nearest to war: irv, jai, delivering, membrane, emails, iigs, resist, reducible,
# Nearest to but: and, however, xie, fallacious, made, hexagon, larkin, which,
# Average loss at step 12000: 3.173132
# Average loss at step 14000: 3.128782
# Average loss at step 16000: 3.150237
# Average loss at step 18000: 3.103638
# Average loss at step 20000: 2.994977
# Nearest to its: their, his, the, electrophilic, torch, her, my, josef,
# Nearest to however: but, regatta, that, immortality, mirror, holiday, seized, leveraged,
# Nearest to more: less, very, superceded, most, rather, nee, syllable, bonded,
# Nearest to be: is, been, being, refer, have, were, amal, was,
# Nearest to of: watson, enclosed, concurrency, lachaise, clytemnestra, orioles, boolean, rumors,
# Nearest to united: utilize, mathura, priming, same, requiring, shangri, restraints, senate,
# Nearest to at: in, bingen, until, during, amaziah, on, falcons, evaporative,
# Nearest to time: communities, year, loeb, reason, fjord, days, ect, scarlet,
# Nearest to may: can, must, could, might, will, should, would, cannot,
# Nearest to has: had, have, was, is, dachau, having, includes, bobby,
# Nearest to history: spared, homeworld, university, arianespace, grantham, implosive, geography, sobib,
# Nearest to known: such, seer, used, tretyakov, well, cerf, described, detriment,
# Nearest to world: counseling, bijapur, alomari, ztas, senator, gallia, tau, capital,
# Nearest to than: quadra, or, smirnov, hooking, climatic, hestia, michele, overthrowing,
# Nearest to war: emails, iigs, membrane, albert, irv, delivering, completed, resist,
# Nearest to but: however, and, while, planina, prasad, fallacious, darth, which,
# Average loss at step 22000: 3.049539
# Average loss at step 24000: 3.024048
# Average loss at step 26000: 2.986244
# Average loss at step 28000: 3.012099
# Average loss at step 30000: 2.986216
# Nearest to its: their, his, the, her, my, electrophilic, whose, our,
# Nearest to however: but, that, regatta, although, mirror, which, leveraged, where,
# Nearest to more: less, very, most, rather, nee, highly, superceded, afar,
# Nearest to be: been, being, was, is, provide, were, refer, amal,
# Nearest to of: concurrency, enclosed, hopi, clytemnestra, watson, concerning, selby, groundwork,
# Nearest to united: mathura, utilize, priming, same, disqualification, phenomenology, beretta, intercepted,
# Nearest to at: amaziah, in, during, until, on, connacht, primarily, falcons,
# Nearest to time: loeb, year, reason, disbelief, way, scarlet, cucumbers, mid,
# Nearest to may: can, must, could, will, might, would, should, cannot,
# Nearest to has: had, have, is, was, includes, having, yet, dachau,
# Nearest to history: spared, arianespace, olympics, development, geography, university, admirals, sobib,
# Nearest to known: used, described, defined, such, tretyakov, cerf, well, viewed,
# Nearest to world: counseling, alomari, bijapur, downs, ztas, cold, capital, tau,
# Nearest to than: or, quadra, climatic, hooking, assuming, apocr, amnon, hestia,
# Nearest to war: emails, bbc, iigs, albert, completed, breakbeat, decrypted, amalgamated,
# Nearest to but: however, and, planina, while, see, which, prasad, kish,
# Average loss at step 32000: 2.847048
# Average loss at step 34000: 2.948922
# Average loss at step 36000: 2.936953
# Average loss at step 38000: 2.942591
# Average loss at step 40000: 2.919192
# Nearest to its: their, his, the, her, my, whose, our, your,
# Nearest to however: but, although, that, regatta, though, seized, mmm, tld,
# Nearest to more: less, most, very, highly, nee, rather, afar, superceded,
# Nearest to be: been, being, is, was, were, refer, are, provide,
# Nearest to of: concurrency, quinn, professes, rumors, concerning, hopi, arrakis, lachaise,
# Nearest to united: mathura, utilize, same, intercepted, priming, phenomenology, disqualification, ussachevsky,
# Nearest to at: amaziah, on, during, until, secam, in, over, falcons,
# Nearest to time: loeb, year, disbelief, reason, fjord, scarlet, mid, diabelli,
# Nearest to may: can, could, must, will, would, might, should, cannot,
# Nearest to has: had, have, is, was, having, includes, dachau, mccoy,
# Nearest to history: olympics, question, communist, geography, arianespace, videogame, pompey, whole,
# Nearest to known: used, described, defined, viewed, considered, regarded, balder, tretyakov,
# Nearest to world: counseling, alomari, bijapur, ztas, approaching, profession, repeats, tau,
# Nearest to than: or, quadra, but, climatic, assuming, apocr, hooking, bulgarians,
# Nearest to war: emails, iigs, heritage, bbc, albert, decrypted, appropriateness, membrane,
# Nearest to but: however, and, while, than, prasad, see, which, although,
# Average loss at step 42000: 2.942655
# Average loss at step 44000: 2.942054
# Average loss at step 46000: 2.901000
# Average loss at step 48000: 2.870767
# Average loss at step 50000: 2.852626
# Nearest to its: their, his, the, her, our, my, whose, your,
# Nearest to however: but, that, although, regatta, though, where, dhul, seized,
# Nearest to more: less, most, very, highly, rather, nee, faster, superceded,
# Nearest to be: been, being, is, provide, was, are, refer, were,
# Nearest to of: concurrency, documenting, selby, concerning, in, enclosed, quinn, hopi,
# Nearest to united: mathura, utilize, same, intercepted, beretta, phenomenology, priming, ussachevsky,
# Nearest to at: in, during, amaziah, on, connacht, until, falcons, bingen,
# Nearest to time: disbelief, loeb, year, scarlet, fjord, control, month, canonically,
# Nearest to may: can, could, must, might, will, should, would, cannot,
# Nearest to has: had, have, is, includes, was, having, mccoy, chemically,
# Nearest to history: olympics, arianespace, view, videogame, reign, reoccupied, communist, pompey,
# Nearest to known: used, described, defined, viewed, regarded, such, considered, balder,
# Nearest to world: counseling, alomari, bijapur, profession, approaching, ztas, iraq, repeats,
# Nearest to than: quadra, or, assuming, climatic, apocr, bulgarians, much, while,
# Nearest to war: emails, heritage, bbc, decrypted, iigs, breakbeat, appropriateness, albert,
# Nearest to but: however, and, while, although, see, which, though, theogony,
# Average loss at step 52000: 2.883996
# Average loss at step 54000: 2.863880
# Average loss at step 56000: 2.860722
# Average loss at step 58000: 2.759682
# Average loss at step 60000: 2.826094
# Nearest to its: their, his, the, her, our, whose, your, my,
# Nearest to however: but, although, that, though, while, regatta, where, tld,
# Nearest to more: less, most, very, highly, rather, larger, faster, smaller,
# Nearest to be: been, being, is, was, become, provide, theirs, refer,
# Nearest to of: concurrency, concerning, quinn, professes, selby, hopi, clarkson, documenting,
# Nearest to united: mathura, intercepted, utilize, phenomenology, priming, beretta, u, disqualification,
# Nearest to at: during, in, amaziah, on, balmoral, refuted, falcons, evaporative,
# Nearest to time: loeb, year, disbelief, fjord, month, period, mesogens, days,
# Nearest to may: can, could, must, might, would, will, should, cannot,
# Nearest to has: had, have, is, was, includes, having, mccoy, contains,
# Nearest to history: olympics, arianespace, view, reign, videogame, province, reoccupied, roms,
# Nearest to known: defined, viewed, described, balder, used, regarded, possible, considered,
# Nearest to world: counseling, alomari, bijapur, profession, approaching, bulgarian, commando, gdb,
# Nearest to than: quadra, assuming, or, climatic, while, bulgarians, much, safeguarding,
# Nearest to war: emails, heritage, bbc, decrypted, membrane, iigs, breakbeat, appropriateness,
# Nearest to but: however, and, although, while, kish, which, see, occur,
# Average loss at step 62000: 2.832941
# Average loss at step 64000: 2.782633
# Average loss at step 66000: 2.770684
# Average loss at step 68000: 2.719862
# Average loss at step 70000: 2.776397
# Nearest to its: their, his, the, whose, her, our, my, electrophilic,
# Nearest to however: but, although, though, that, while, regatta, witchcraft, and,
# Nearest to more: less, most, very, highly, quite, rather, faster, larger,
# Nearest to be: been, being, is, become, refer, was, theirs, have,
# Nearest to of: quinn, concerning, concurrency, in, mailing, regarding, selby, professes,
# Nearest to united: mathura, intercepted, phenomenology, utilize, u, beretta, priming, senate,
# Nearest to at: in, during, on, until, balmoral, amaziah, bingen, ene,
# Nearest to time: days, disbelief, year, loeb, fjord, month, period, reason,
# Nearest to may: can, could, might, must, should, would, will, cannot,
# Nearest to has: had, have, is, includes, was, having, mccoy, requires,
# Nearest to history: olympics, arianespace, province, reign, university, whole, list, videogame,
# Nearest to known: defined, described, viewed, such, regarded, considered, possible, balder,
# Nearest to world: counseling, alomari, profession, bijapur, cold, bulgarian, commando, reprints,
# Nearest to than: quadra, assuming, or, much, climatic, abundantly, bulgarians, hh,
# Nearest to war: emails, bbc, heritage, breakbeat, membrane, decrypted, ptl, iigs,
# Nearest to but: however, although, and, while, though, miraculously, which, mysteriously,
# Average loss at step 72000: 2.802452
# Average loss at step 74000: 2.660792
# Average loss at step 76000: 2.799186
# Average loss at step 78000: 2.818345
# Average loss at step 80000: 2.785807
# Nearest to its: their, his, the, whose, her, electrophilic, our, my,
# Nearest to however: but, although, though, that, regatta, while, initially, during,
# Nearest to more: less, most, very, highly, quite, rather, larger, smaller,
# Nearest to be: been, become, being, was, is, refer, achieve, were,
# Nearest to of: concerning, concurrency, selby, definitive, quinn, cigars, mailing, clarkson,
# Nearest to united: mathura, intercepted, phenomenology, u, utilize, senate, beretta, priming,
# Nearest to at: in, during, within, balmoral, ene, amaziah, refuted, on,
# Nearest to time: loeb, days, year, disbelief, respondents, fjord, period, month,
# Nearest to may: can, could, might, would, must, should, will, cannot,
# Nearest to has: had, have, is, was, includes, having, contains, requires,
# Nearest to history: olympics, arianespace, whole, geography, fellow, infix, list, indonesia,
# Nearest to known: defined, viewed, regarded, used, possible, considered, described, recognized,
# Nearest to world: bijapur, alomari, counseling, profession, commando, bulgarian, repeats, match,
# Nearest to than: assuming, quadra, or, much, climatic, abundantly, apocr, safeguarding,
# Nearest to war: emails, defence, heritage, bbc, decrypted, appropriateness, breakbeat, ptl,
# Nearest to but: however, although, and, though, which, while, occur, miraculously,
# Average loss at step 82000: 2.672475
# Average loss at step 84000: 2.771917
# Average loss at step 86000: 2.743165
# Average loss at step 88000: 2.757876
# Average loss at step 90000: 2.746005
# Nearest to its: their, his, whose, the, her, electrophilic, our, glucose,
# Nearest to however: but, although, though, that, while, regatta, unfortunately, whereas,
# Nearest to more: less, most, highly, very, quite, increasingly, rather, bigger,
# Nearest to be: been, being, become, is, refer, was, theirs, achieve,
# Nearest to of: concerning, concurrency, regarding, mailing, lachaise, professes, definitive, selby,
# Nearest to united: mathura, intercepted, habsburg, phenomenology, beretta, utilize, senate, ussachevsky,
# Nearest to at: during, in, amaziah, refuted, within, premiers, falcons, bok,
# Nearest to time: loeb, month, year, respondents, days, disbelief, reason, fjord,
# Nearest to may: can, could, might, would, must, should, will, cannot,
# Nearest to has: had, have, is, was, includes, having, requires, contains,
# Nearest to history: olympics, list, university, geography, development, timeline, indonesia, reoccupied,
# Nearest to known: defined, viewed, regarded, possible, considered, recognized, opposed, called,
# Nearest to world: alomari, bijapur, profession, nation, iraq, match, commando, counseling,
# Nearest to than: assuming, quadra, or, much, climatic, abundantly, hestia, apocr,
# Nearest to war: emails, appropriateness, defence, heritage, decrypted, bbc, hag, fronti,
# Nearest to but: however, although, though, while, see, which, miraculously, mysteriously,
# Average loss at step 92000: 2.687199
# Average loss at step 94000: 2.728596
# Average loss at step 96000: 2.708888
# Average loss at step 98000: 2.387428
# Average loss at step 100000: 2.420947
# Nearest to its: their, his, whose, her, electrophilic, the, our, glucose,
# Nearest to however: but, although, though, that, while, initially, during, where,
# Nearest to more: less, most, highly, very, quite, increasingly, rather, bigger,
# Nearest to be: been, being, become, is, was, refer, achieve, were,
# Nearest to of: concerning, concurrency, definitive, quinn, professes, establishes, clarkson, regarding,
# Nearest to united: mathura, intercepted, senate, u, phenomenology, habsburg, opening, utilize,
# Nearest to at: in, during, amaziah, on, near, refuted, bok, ene,
# Nearest to time: loeb, days, month, year, respondents, disbelief, period, reason,
# Nearest to may: can, could, might, must, would, should, will, cannot,
# Nearest to has: had, have, is, includes, was, having, maintains, requires,
# Nearest to history: list, olympics, indonesia, university, reign, infix, timeline, arianespace,
# Nearest to known: defined, regarded, viewed, possible, recognized, opposed, considered, described,
# Nearest to world: alomari, profession, gdb, counseling, thickening, iraq, bijapur, ztas,
# Nearest to than: quadra, or, assuming, much, hestia, climatic, apocr, stiff,
# Nearest to war: emails, wars, heritage, bbc, decrypted, fronti, defence, appropriateness,
# Nearest to but: however, although, though, and, while, mysteriously, which, miraculously,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
